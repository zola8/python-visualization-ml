# %% [markdown]
# # Chapter 2 - Selecting and finding desired data
#
# https://tutswiki.com/pandas-cookbook/chapter2/

# %%
import pandas as pd

complaints = pd.read_csv('service-requests-311.csv')
# Out:
# C:\Users\zola\AppData\Local\Temp\ipykernel_2944\2908862327.py:3: DtypeWarning: Columns (0: Incident Zip) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints = pd.read_csv('service-requests-311.csv')

# %%
complaints[:3]
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department          Illegal Parking
# 2  New York City Police Department       Noise - Commercial
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk      11432.0
# 1  Commercial Overnight Parking      Street/Sidewalk      11378.0
# 2              Loud Music/Party  Club/Bar/Restaurant      10032.0
#
#    Incident Address  ... Bridge Highway Name Bridge Highway Direction  \
# 0  90-03 169 STREET  ...                 NaN                      NaN
# ...

# %%
complaints['Complaint Type']
# Out:
# 0         Noise - Street/Sidewalk
# 1                 Illegal Parking
# 2              Noise - Commercial
# 3                 Noise - Vehicle
# 4                          Rodent
#                    ...
# 111064    Maintenance or Facility
# 111065            Illegal Parking
# 111066    Noise - Street/Sidewalk
# 111067         Noise - Commercial
# 111068           Blocked Driveway
# Name: Complaint Type, Length: 111069, dtype: str

# %%
complaints['Complaint Type'][:3]
# Out:
# 0    Noise - Street/Sidewalk
# 1            Illegal Parking
# 2         Noise - Commercial
# Name: Complaint Type, dtype: str

# %%
complaints['Complaint Type'].value_counts()
# Out:
# Complaint Type
# HEATING                    14200
# GENERAL CONSTRUCTION        7471
# Street Light Condition      7117
# DOF Literature Request      5797
# PLUMBING                    5373
#                            ...
# Open Flame Permit              1
# DWD                            1
# Highway Sign - Damaged         1
# Ferry Permit                   1
# X-Ray Machine/Equipment        1
# Name: count, Length: 165, dtype: int64

# %%
complaints[['Complaint Type', 'Descriptor', 'Borough']][:3]
# Out:
#             Complaint Type                    Descriptor    Borough
# 0  Noise - Street/Sidewalk                  Loud Talking     QUEENS
# 1          Illegal Parking  Commercial Overnight Parking     QUEENS
# 2       Noise - Commercial              Loud Music/Party  MANHATTAN

# %%
# top 10 complaint type

complaints['Complaint Type'].value_counts()[:10]
# Out:
# Complaint Type
# HEATING                   14200
# GENERAL CONSTRUCTION       7471
# Street Light Condition     7117
# DOF Literature Request     5797
# PLUMBING                   5373
# PAINT - PLASTER            5149
# Blocked Driveway           4590
# NONCONST                   3998
# Street Condition           3473
# Illegal Parking            3343
# Name: count, dtype: int64

# %%
complaints['Complaint Type'].value_counts()[-3:]
# Out:
# Complaint Type
# Highway Sign - Damaged     1
# Ferry Permit               1
# X-Ray Machine/Equipment    1
# Name: count, dtype: int64

# %%
complaints['Complaint Type'].value_counts()[:10].plot(kind='bar')
# Out:
# <Axes: xlabel='Complaint Type'>
