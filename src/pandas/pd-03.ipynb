# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %%
stock_df = yf.download(tickers="EPAM")

stock_df.tail(3)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker            EPAM        EPAM        EPAM        EPAM     EPAM
# Date
# 2026-02-24  128.820007  132.759995  128.000000  130.500000  1843700
# 2026-02-25  131.080002  132.000000  125.570000  130.380005  1335900
# 2026-02-26  138.619995  140.000000  132.229996  132.750000   982700

# %%
stock_df.Close.plot()
# Out:
# <Axes: xlabel='Date'>
