# %%
from sklearn.datasets import make_blobs, make_moons
# random data maker

# %%
blobs = make_blobs(n_features=4, n_samples=10, centers=3)

blobs
# Out:
# (array([[ 4.9865474 ,  7.6930225 ,  0.6491374 ,  2.57952272],
#         [-2.78378235,  2.1764068 , -0.25414784,  9.80075172],
#         [ 3.8118966 ,  8.03042446,  0.21203216,  2.54097401],
#         [ 2.55830633,  6.89721368, -0.45174604,  2.96650493],
#         [ 3.7230508 ,  7.69906715, -1.20602416, -1.71674138],
#         [-0.88956957,  2.57743139,  0.06709986,  8.5857832 ],
#         [ 4.72581821,  5.720353  , -1.54399574, -1.64466703],
#         [-0.67680898,  2.38075203, -0.25812116,  7.71139124],
#         [ 4.92850469,  6.54051687, -1.4204208 , -1.16423103],
#         [ 4.55189807,  5.37665515, -1.16281827, -0.24976931]]),
#  array([2, 1, 2, 2, 0, 1, 0, 1, 0, 0]))

# %%
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples=500, centers=5)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
# first and second dimension data, color = (y) labels

# %%
X, y = make_moons(noise=0.01)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
