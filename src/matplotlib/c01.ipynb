# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris
# https://www.youtube.com/watch?v=OZOOLe2imFo

# %%
X = np.random.random(50) * 100
y = np.random.random(50) * 100

# %%
plt.scatter(X, y)

# %%
df = pd.DataFrame(
    {'one': np.random.random(10),
     'two': np.random.random(10)}
)

# %%
df.plot()
# Out:
# <Axes: >

# %%
plt.scatter(df['one'], df['two'])

# %%
df = pd.DataFrame({'col_name_1':np.random.rand(20), 'col_name_2': np.random.rand(20)})

# %%
df.plot.scatter(x='col_name_1', y='col_name_2', style='x')
# Out:
# <Axes: xlabel='col_name_1', ylabel='col_name_2'>

# %%
years = [x for x in range(2000, 2027)]
weights = np.random.random(27)

# %%
plt.plot(years, weights)

# %%
plt.bar(years, weights)
# Out:
# <BarContainer object of 27 artists>
