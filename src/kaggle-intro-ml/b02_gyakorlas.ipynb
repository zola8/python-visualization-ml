# %% [markdown]
# ### load data

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

df = pd.read_csv('data/train.csv')

# %% [markdown]
# ### select features + target

# %%
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = df[features]
y = df.SalePrice

# %% [markdown]
# ### divide data into training + validation subsets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### score_model

# %%
def score_model(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    score = mean_absolute_error(y_test, preds)
    print('Model: ', model, 'MAE:', score)
    return score

# %%
model_1 = ('model_1', DecisionTreeRegressor(max_depth=5, random_state=1))
model_2 = ('model_2', DecisionTreeRegressor(max_leaf_nodes=100, random_state=1))
model_3 = ('model_3', RandomForestRegressor(random_state=1))
model_4 = ('model_4', RandomForestRegressor(n_estimators=50, random_state=0))
model_5 = ('model_5', RandomForestRegressor(n_estimators=100, random_state=0))
model_6 = ('model_6', RandomForestRegressor(n_estimators=100, criterion='absolute_error', random_state=0))
model_7 = ('model_7', RandomForestRegressor(n_estimators=200, min_samples_split=20, random_state=0))
model_8 = ('model_8', RandomForestRegressor(n_estimators=100, max_depth=7, random_state=0))
mae_results = {}

models = [model_1, model_2, model_3, model_4, model_5, model_6, model_7, model_8]

for model_name, model in models:
    score = score_model(model, X_train, X_test, y_train, y_test)
    mae_results[model_name] = score
# Out:
# Model:  DecisionTreeRegressor(max_depth=5, random_state=1) MAE: 28374.661757532685
# Model:  DecisionTreeRegressor(max_leaf_nodes=100, random_state=1) MAE: 27935.885755730505
# Model:  RandomForestRegressor(random_state=1) MAE: 22255.863997064578
# Model:  RandomForestRegressor(n_estimators=50, random_state=0) MAE: 22074.65826484018
# Model:  RandomForestRegressor(random_state=0) MAE: 21979.93948630137
# Model:  RandomForestRegressor(criterion='absolute_error', random_state=0) MAE: 22471.96893835616
# Model:  RandomForestRegressor(min_samples_split=20, n_estimators=200, random_state=0) MAE: 22508.587520094
# Model:  RandomForestRegressor(max_depth=7, random_state=0) MAE: 22439.36940279305

# %%
a = sorted(mae_results.items(), key=lambda x: x[1], reverse=False)
a
# Out:
# [('model_5', 21979.93948630137),
#  ('model_4', 22074.65826484018),
#  ('model_3', 22255.863997064578),
#  ('model_8', 22439.36940279305),
#  ('model_6', 22471.96893835616),
#  ('model_7', 22508.587520094),
#  ('model_2', 27935.885755730505),
#  ('model_1', 28374.661757532685)]
