# %% [markdown]
# # Underfitting and Overfitting

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor


def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return mae

# %%
import pandas as pd

df = pd.read_csv('data/melb_data.csv')
df = df.dropna()

X = df[['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude']]
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=0)

# %%
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" % (max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  347380
# Max leaf nodes: 50  		 Mean Absolute Error:  258171
# Max leaf nodes: 500  		 Mean Absolute Error:  243495
# Max leaf nodes: 5000  		 Mean Absolute Error:  255575

# %% [markdown]
# # example 2

# %%
home_data = pd.read_csv('data/train.csv')
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[features]
y = home_data.SalePrice
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
iowa_model = DecisionTreeRegressor(random_state=1)
iowa_model.fit(train_X, train_y)
val_predictions = iowa_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("Validation MAE: {:,.0f}".format(val_mae))
# Out:
# Validation MAE: 29,653

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return (mae)

# %%
candidate_max_leaf_nodes = [5, 25, 50, 100, 250, 500]
result = {}

for i in candidate_max_leaf_nodes:
    curr_mae = get_mae(i, train_X, val_X, train_y, val_y)
    result[i] = curr_mae
    print(f"{i} - mae: {curr_mae}")
# Out:
# 5 - mae: 35044.51299744237
# 25 - mae: 29016.41319191076
# 50 - mae: 27405.930473214907
# 100 - mae: 27282.50803885739
# 250 - mae: 27893.822225701646
# 500 - mae: 29454.18598068598

# %%
result
# Out:
# {5: 35044.51299744237,
#  25: 29016.41319191076,
#  50: 27405.930473214907,
#  100: 27282.50803885739,
#  250: 27893.822225701646,
#  500: 29454.18598068598}

# %%
min(result, key=result.get)
# Out:
# 100

# %%
min(result.values())
# Out:
# 27282.50803885739

# %%
min(result.items(), key=lambda x: x[1])
# Out:
# (100, 27282.50803885739)

# %%
result.items()
# Out:
# dict_items([(5, 35044.51299744237), (25, 29016.41319191076), (50, 27405.930473214907), (100, 27282.50803885739), (250, 27893.822225701646), (500, 29454.18598068598)])
