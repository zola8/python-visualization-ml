# %%
import yfinance as yf
import matplotlib.pyplot as plt

yf.__version__
# Out:
# '1.2.0'

# %%
df = yf.download(tickers=['MSFT', 'EPAM', 'GOOGL', 'UBS'], period="max")
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
df
# Out:
# Price            Close                                           High  \
# Ticker            EPAM       GOOGL        MSFT        UBS        EPAM
# Date
# 1986-03-13         NaN         NaN    0.059253        NaN         NaN
# 1986-03-14         NaN         NaN    0.061369        NaN         NaN
# 1986-03-17         NaN         NaN    0.062428        NaN         NaN
# 1986-03-18         NaN         NaN    0.060840        NaN         NaN
# 1986-03-19         NaN         NaN    0.059782        NaN         NaN
# ...                ...         ...         ...        ...         ...
# 2026-02-23  129.960007  311.489990  384.470001  41.529999  137.199997
# 2026-02-24  128.820007  310.899994  389.000000  41.200001  132.759995
# 2026-02-25  131.080002  312.899994  400.600006  41.540001  132.000000
# 2026-02-26  138.619995  307.380005  401.720001  41.900002  140.000000
# 2026-02-27  141.000000  311.760010  392.739990  41.430000  141.119995
#
# ...

# %%
epam = df.xs('EPAM', axis = 1, level = 'Ticker')
msft = df.xs('MSFT', axis = 1, level = 'Ticker')
googl = df.xs('GOOGL', axis = 1, level = 'Ticker')
ubs = df.xs('UBS', axis = 1, level = 'Ticker')

# %%
epam
# Out:
# Price            Close        High         Low        Open     Volume
# Date
# 1986-03-13         NaN         NaN         NaN         NaN        NaN
# 1986-03-14         NaN         NaN         NaN         NaN        NaN
# 1986-03-17         NaN         NaN         NaN         NaN        NaN
# 1986-03-18         NaN         NaN         NaN         NaN        NaN
# 1986-03-19         NaN         NaN         NaN         NaN        NaN
# ...                ...         ...         ...         ...        ...
# 2026-02-23  129.960007  137.199997  129.039993  136.500000  1777400.0
# 2026-02-24  128.820007  132.759995  128.000000  130.500000  1843700.0
# 2026-02-25  131.080002  132.000000  125.570000  130.380005  1335900.0
# 2026-02-26  138.619995  140.000000  132.229996  132.750000   982700.0
# 2026-02-27  141.000000  141.119995  134.009995  135.490005  1805900.0
#
# [10068 rows x 5 columns]

# %%
epam_not_adjusted = yf.download(tickers='EPAM', period="max", auto_adjust=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
epam_not_adjusted
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            EPAM        EPAM        EPAM        EPAM        EPAM
# Date
# 2012-02-08   14.000000   14.000000   15.050000   13.250000   13.750000
# 2012-02-09   13.910000   13.910000   14.220000   13.750000   14.170000
# 2012-02-10   13.960000   13.960000   14.030000   13.770000   14.000000
# 2012-02-13   13.650000   13.650000   14.420000   13.630000   13.910000
# 2012-02-14   13.440000   13.440000   13.790000   13.300000   13.600000
# ...                ...         ...         ...         ...         ...
# 2026-02-23  129.960007  129.960007  137.199997  129.039993  136.500000
# 2026-02-24  128.820007  128.820007  132.759995  128.000000  130.500000
# 2026-02-25  131.080002  131.080002  132.000000  125.570000  130.380005
# 2026-02-26  138.619995  138.619995  140.000000  132.229996  132.750000
# 2026-02-27  141.000000  141.000000  141.119995  134.009995  135.490005
#
# Price        Volume
# ...

# %%
epam['Close'].plot(title = 'EPAM')
# Out:
# <Axes: title={'center': 'EPAM'}, xlabel='Date'>

# %%
epam.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 10068 entries, 1986-03-13 to 2026-02-27
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   3534 non-null   float64
#  1   High    3534 non-null   float64
#  2   Low     3534 non-null   float64
#  3   Open    3534 non-null   float64
#  4   Volume  3534 non-null   float64
# dtypes: float64(5)
# memory usage: 471.9 KB

# %%
msft.info
# Out:
# <bound method DataFrame.info of Price            Close        High         Low        Open      Volume
# Date
# 1986-03-13    0.059253    0.061899    0.053963    0.053963  1031788800
# 1986-03-14    0.061369    0.062428    0.059253    0.059253   308160000
# 1986-03-17    0.062428    0.062957    0.061369    0.061369   133171200
# 1986-03-18    0.060840    0.062957    0.060311    0.062428    67766400
# 1986-03-19    0.059782    0.061369    0.059253    0.060840    47894400
# ...                ...         ...         ...         ...         ...
# 2026-02-23  384.470001  395.359985  383.100006  395.000000    43238300
# 2026-02-24  389.000000  389.359985  381.709991  384.140015    33884700
# 2026-02-25  400.600006  401.470001  390.160004  390.529999    43625500
# 2026-02-26  401.720001  407.489990  398.739990  404.709991    34405900
# 2026-02-27  392.739990  396.820007  389.880005  390.880005    51276300
#
# [10068 rows x 5 columns]>
